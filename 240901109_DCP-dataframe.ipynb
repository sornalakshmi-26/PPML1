# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.032422  1.524381 -0.479912
# b       NaN       NaN       NaN
# c -0.259261  0.534438  0.374202
# d  1.324185 -0.389980 -1.211959
# e       NaN       NaN       NaN
# f -0.737280 -0.655858  1.339633
#
#
# Dropped DataFrame
#          one       two     three
# a -0.032422  1.524381 -0.479912
# c -0.259261  0.534438  0.374202
# d  1.324185 -0.389980 -1.211959
# f -0.737280 -0.655858  1.339633

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.277357  0.407915  0.968186
# b       NaN       NaN       NaN
# c -0.161584 -0.379157 -1.600302
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.277357  0.407915  0.968186
# b  0.000000  0.000000  0.000000
# c -0.161584 -0.379157 -1.600302

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -1.063907  0.391675 -0.651644
# b       NaN       NaN       NaN
# c  0.868990 -1.821570  2.387250
# d -1.424459 -0.159759  1.412464
# e       NaN       NaN       NaN
# f -2.152022 -0.200465  0.500060
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.bfill())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.256674 -0.591988  0.422198
# b       NaN       NaN       NaN
# c  0.294402  0.444692  1.622164
# d -1.120487 -2.013930  0.511686
# e       NaN       NaN       NaN
# f  0.165161  0.965549  0.835196
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.256674 -0.591988  0.422198
# b  0.294402  0.444692  1.622164
# c  0.294402  0.444692  1.622164
# d -1.120487 -2.013930  0.511686
# e  0.165161  0.965549  0.835196
# f  0.165161  0.965549  0.835196
