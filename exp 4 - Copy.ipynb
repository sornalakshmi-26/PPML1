# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.105290  0.595548 -2.038714
# b       NaN       NaN       NaN
# c -0.630420 -0.394991  0.091548
# d -1.789294 -0.019061 -1.471530
# e       NaN       NaN       NaN
# f -1.455159  0.665663 -0.962354
#
#
# Dropped DataFrame
#          one       two     three
# a -0.105290  0.595548 -2.038714
# c -0.630420 -0.394991  0.091548
# d -1.789294 -0.019061 -1.471530
# f -1.455159  0.665663 -0.962354

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.222681 -1.217741  0.706042
# b       NaN       NaN       NaN
# c  0.068372  0.863326 -0.495771
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.222681 -1.217741  0.706042
# b  0.000000  0.000000  0.000000
# c  0.068372  0.863326 -0.495771

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -1.164095 -0.254191 -0.032812
# b       NaN       NaN       NaN
# c  1.110512 -0.812876 -1.328627
# d  0.137373  0.559077  0.432151
# e       NaN       NaN       NaN
# f  0.675362  0.579546  0.719840
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.544457  1.423432 -0.948395
# b       NaN       NaN       NaN
# c -0.486653  1.364433  0.612225
# d -1.078563 -1.203794  0.865752
# e       NaN       NaN       NaN
# f  1.601544 -0.986118  1.726964
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.544457  1.423432 -0.948395
# b -0.486653  1.364433  0.612225
# c -0.486653  1.364433  0.612225
# d -1.078563 -1.203794  0.865752
# e  1.601544 -0.986118  1.726964
# f  1.601544 -0.986118  1.726964
